ulling manifest
# pulling fd7b6731c33c:  96% ▕▏ 8.7 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  97% ▕▏ 8.8 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  97% ▕▏ 8.8 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  97% ▕▏ 8.8 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  98% ▕▏ 8.8 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  98% ▕▏ 8.9 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  98% ▕▏ 8.9 GB/9.1 GB  174 MB/s      1spulling manifest
# pulling fd7b6731c33c:  98% ▕▏ 8.9 GB/9.1 GB  174 MB/s      0spulling manifest
# pulling fd7b6731c33c:  99% ▕▏ 8.9 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c:  99% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c:  99% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.0 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB/9.1 GB  176 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB/9.1 GB  162 MB/s      0spulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B                         pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# ...
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠦ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠧ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠇ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠏ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠋ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠙ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠹ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠸ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠼ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest ⠴ pulling manifest
# pulling fd7b6731c33c: 100% ▕▏ 9.1 GB
# pulling 32695b892af8: 100% ▕▏  275 B
# pulling fa8235e5b48f: 100% ▕▏ 1.1 KB
# pulling 45a1c652dddc: 100% ▕▏   82 B
# pulling f5d6f49c6477: 100% ▕▏  486 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !pip install ollama faiss-cpu sentence-transformers numpy
# Out:
# Collecting ollama
#   Downloading ollama-0.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: httpx<0.29,>=0.27 in /usr/local/lib/python3.11/dist-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from ollama) (2.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx<0.29,>=0.27->ollama) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.13.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Downloading ollama-0.4.8-py3-none-any.whl (13 kB)
# Downloading faiss_cpu-1.11.0-cp311-cp311-manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 59.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, faiss-cpu, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ollama, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed faiss-cpu-1.11.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ollama-0.4.8

# %% [markdown]
# Unoptimized Agent

# %%
import ollama
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import time
import logging
from typing import List, Tuple

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class SimpleAgent:
    def __init__(self):
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        self.dimension = 384  # Dimension of the embedding model
        self.index = faiss.IndexFlatL2(self.dimension)
        self.documents = []
        self.token_usage = 0
        self.query_times = []

    def embed_text(self, text: str) -> np.ndarray:
        """Generate embedding for a given text."""
        return self.embedding_model.encode([text])[0]

    def add_document(self, document: str):
        """Add a document to the FAISS index."""
        start_time = time.time()
        embedding = self.embed_text(document)
        self.index.add(np.array([embedding], dtype=np.float32))
        self.documents.append(document)
        logger.info(f"Added document. Time: {time.time() - start_time:.4f}s")

    def query(self, question: str, k: int = 1) -> Tuple[str, int]:
        """Query the agent with a question."""
        start_time = time.time()

        # Generate embedding for the question
        question_embedding = self.embed_text(question)

        # Search FAISS index
        distances, indices = self.index.search(np.array([question_embedding], dtype=np.float32), k)

        # Retrieve relevant documents
        context = [self.documents[idx] for idx in indices[0] if idx < len(self.documents)]
        context_text = "\n".join(context)

        # Prepare prompt (unoptimized: verbose and redundant)
        prompt = f"""
        You are a helpful assistant. Given the following context and question, provide a detailed answer.

        Context:
        {context_text}

        Question:
        {question}

        Please provide a comprehensive response with all relevant details.
        """

        # Call Ollama Phi-4
        response = ollama.chat(
            model='phi4',
            messages=[{'role': 'user', 'content': prompt}]
        )

        # Track token usage (approximate)
        prompt_tokens = len(prompt.split())
        response_tokens = len(response['message']['content'].split())
        total_tokens = prompt_tokens + response_tokens
        self.token_usage += total_tokens

        # Track query time
        query_time = time.time() - start_time
        self.query_times.append(query_time)

        logger.info(f"Query processed. Time: {query_time:.4f}s, Tokens: {total_tokens}")

        return response['message']['content'], total_tokens

    def get_performance_metrics(self) -> dict:
        """Return performance metrics."""
        return {
            'total_token_usage': self.token_usage,
            'average_query_time': np.mean(self.query_times) if self.query_times else 0,
            'number_of_queries': len(self.query_times)
        }

# Example usage
if __name__ == "__main__":
    agent = SimpleAgent()

    # Add sample documents
    documents = [
        "The capital of France is Paris.",
        "Python is a popular programming language.",
        "The sun is a star."
    ]

    for doc in documents:
        agent.add_document(doc)

    # Test queries
    queries = [
        "What is the capital of France?",
        "What is Python?",
        "Is the sun a star?"
    ]

    for query in queries:
        answer, tokens = agent.query(query)
        print(f"Query: {query}")
        print(f"Answer: {answer}")
        print(f"Tokens used: {tokens}\n")

    # Print performance metrics
    metrics = agent.get_performance_metrics()
    print("Performance Metrics:")
    print(f"Total Token Usage: {metrics['total_token_usage']}")
    print(f"Average Query Time: {metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {metrics['number_of_queries']}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Query: What is the capital of France?
# Answer: The capital of France is Paris. This city serves as both the political and cultural center of the country. Here are some detailed insights about Paris:
#
# 1. **Geography and Demographics**:
#    - Located in the north-central part of France, along the Seine River, Paris covers an area of approximately 105 square kilometers.
#    - It is one of the most densely populated cities in Europe with a metropolitan population exceeding 12 million people.
#
# 2. **Historical Significance**:
#    - Paris has been a major center for art, science, and philosophy since the Middle Ages. The city is home to numerous historical landmarks such as Notre-Dame Cathedral, the Eiffel Tower, and the Louvre Museum.
#    - Historically, it played a central role in events like the French Revolution and both World Wars.
#
# 3. **Cultural Influence**:
#    - Paris is often referred to as "The City of Light" (La Ville Lumière), both because of its leading role during the Age of Enlightenment and more literally because it was one of the first large European cities to use gas street lighting.
#    - It boasts a vibrant cultural scene with world-renowned museums, galleries, theaters, and a thriving fashion industry.
#
# 4. **Economic Importance**:
#    - As France’s capital city, Paris is an economic powerhouse both nationally and internationally. It is home to many multinational corporations, banks, and businesses.
#    - The Paris region contributes significantly to the French GDP, making it one of Europe's leading centers for finance, commerce, fashion, science, and the arts.
#
# 5. **Tourism**:
#    - Known as a top global tourist destination, Paris attracts millions of visitors each year who come to see its iconic landmarks, experience its culinary delights, and explore its rich history.
#    - The city is renowned for attractions such as the Eiffel Tower, Louvre Museum (home to the Mona Lisa), Montmartre district, Champs-Élysées, and Palace of Versailles nearby.
#
# 6. **Transportation**:
#    - Paris has an extensive public transportation network that includes buses, trams, a metro system, suburban railways, and RER trains.
#    - The city is also served by two major international airports: Charles de Gaulle Airport (CDG) and Orly Airport (ORY).
#
# In summary, as the capital of France, Paris holds a pivotal role not only in national governance but also in cultural, economic, and historical contexts both within France and internationally.
# Tokens used: 411
#
# Query: What is Python?
# Answer: Python is a high-level, interpreted programming language known for its simplicity and readability, which has contributed to its widespread popularity. It was created by Guido van Rossum and first released in 1991. Here are some key features and aspects of Python:
#
# ### Key Features
#
# 1. **Readability**:
#    - Python emphasizes code readability with its use of significant whitespace. This means that the structure and layout of the code can enhance understanding, making it easier for developers to write clean and maintainable code.
#
# 2. **Simplicity**:
#    - The language is designed to be straightforward and easy to learn. It uses a syntax that allows complex ideas to be expressed in fewer lines of code compared to other languages like C++ or Java.
#
# 3. **Versatility**:
#    - Python supports multiple programming paradigms, including procedural, object-oriented, and functional programming. This flexibility makes it suitable for a wide range of applications, from web development to data analysis.
#
# 4. **Extensive Standard Library**:
#    - Python comes with a large standard library that includes modules and packages for various tasks, such as file I/O, system calls, internet protocols, string operations, and more. This reduces the need for third-party libraries in many cases.
#
# 5. **Interpreted Language**:
#    - Being an interpreted language means that Python code is executed line by line at runtime. This facilitates debugging and testing but can result in slower execution compared to compiled languages like C++.
#
# 6. **Dynamic Typing**:
#    - Variables in Python do not require explicit declaration to reserve memory space, and their type can change during program execution. This feature adds flexibility but requires careful management of variable types.
#
# 7. **Cross-Platform Compatibility**:
#    - Python is available on various platforms, including Windows, macOS, Linux, and others. Its portability makes it a popular choice for developing applications that need to run on multiple operating systems.
#
# 8. **Community and Ecosystem**:
#    - Python has a large and active community of developers who contribute to its development and maintain a wide array of third-party libraries and frameworks. Popular examples include Django for web development, NumPy and Pandas for data analysis, and TensorFlow for machine learning.
#
# 9. **Integration and Embedding**:
#    - Python can be easily integrated with other languages like C/C++ or embedded within them. This makes it suitable for scripting in applications where performance is critical but not the sole focus.
#
# ### Applications
#
# Python's versatility allows it to be used in a variety of domains:
#
# - **Web Development**: Frameworks like Django and Flask enable rapid development of web applications.
# - **Data Science and Machine Learning**: Libraries such as NumPy, Pandas, SciPy, Scikit-learn, and TensorFlow are widely used for data manipulation, analysis, and modeling.
# - **Automation and Scripting**: Python is often used to automate repetitive tasks due to its simplicity and ease of use.
# - **Scientific Computing**: Its mathematical capabilities make it suitable for scientific research and engineering applications.
# - **Education**: Due to its readability and simplicity, Python is a popular language taught in introductory programming courses.
#
# ### Conclusion
#
# Python's combination of simplicity, versatility, and powerful libraries has made it one of the most popular programming languages today. It continues to grow with new features and improvements, driven by an active community of developers. Whether for beginners or experienced programmers, Python offers tools and capabilities that make it a valuable language for various applications.
# Tokens used: 577
#
# Query: Is the sun a star?
# Answer: Yes, the Sun is indeed a star. Here's a comprehensive explanation to clarify why:
#
# ### Definition of a Star
#
# A star is a massive celestial body made primarily of hydrogen and helium that generates energy through nuclear fusion in its core. This process combines lighter atomic nuclei into heavier ones, releasing energy in the form of light and heat.
#
# ### The Sun as a Star
#
# 1. **Composition**:
#    - Like other stars, the Sun is composed mainly of hydrogen (about 74% by mass) and helium (around 24%), with trace amounts of heavier elements like oxygen, carbon, neon, and iron.
#
# 2. **Nuclear Fusion**:
#    - The Sun's energy is produced through nuclear fusion occurring in its core. In this process, hydrogen nuclei combine to form helium, releasing an immense amount of energy that powers the Sun and provides light and heat to our solar system.
#
# 3. **Massive Size**:
#    - The Sun contains about 99.86% of the mass of the entire Solar System. Its diameter is approximately 1.39 million kilometers (about 864,000 miles), making it large enough to fit around 1.3 million Earths inside it.
#
# 4. **Luminosity and Temperature**:
#    - The Sun's surface temperature averages about 5,500 degrees Celsius (9,932 degrees Fahrenheit). It emits light across the electromagnetic spectrum, with peak emission in the visible range, which is why it appears yellowish-white to us.
#
# 5. **Classification**:
#    - The Sun is classified as a G-type main-sequence star, or more commonly known as a "yellow dwarf." Its spectral class is G2V, where 'G' refers to its surface temperature and luminosity class 'V' (Roman numeral five) indicates it is on the main sequence stage of stellar evolution.
#
# 6. **Lifecycle**:
#    - The Sun is approximately 4.6 billion years old and is currently in a stable phase of its lifecycle known as the main-sequence phase, during which it will remain for another roughly 5 billion years before evolving into a red giant and eventually shedding its outer layers to form a planetary nebula.
#
# ### Comparison with Other Stars
#
# - **Similarities**:
#   - Like other stars, the Sun has a similar structure consisting of a core (where nuclear fusion occurs), radiative zone, convective zone, photosphere (visible surface), chromosphere, and corona.
#
# - **Differences**:
#   - The Sun is unique to us as it is the closest star to Earth, providing the necessary conditions for life due to its stable energy output. Most other stars in our galaxy are much farther away and vary significantly in size, temperature, and brightness.
#
# ### Conclusion
#
# In summary, the Sun fits all the criteria of a star: it's a massive, luminous sphere composed mainly of hydrogen and helium, undergoing nuclear fusion in its core. Its characteristics align with those of many other stars observed throughout our galaxy and beyond, solidifying its classification as a G-type main-sequence star. Thus, scientifically speaking, the Sun is not just a star; it is the most central and vital one for life on Earth.
# Tokens used: 517
#
# Performance Metrics:
# Total Token Usage: 1505
# Average Query Time: 56.0968s
# Number of Queries: 3

# %% [markdown]
# You Answer: Optimized Agent with performance metrics

# %% [markdown]
# Optimization Techniques Implemented:
# (List down the techniques you've used)
#
#   1. Prompt Clarity
#
#   2. Context Window Usage
#
#   3. Fallback Strategies
#
#   4. System Instruction Tuning

# %%
#You need to write the agent here in this cell with optimization
import ollama
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import time
import logging
from typing import List, Tuple

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

class SimpleAgent:
    def __init__(self):
        self.embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
        self.dimension = 384  # Dimension of the embedding model
        self.index = faiss.IndexFlatL2(self.dimension)
        self.documents = []
        self.token_usage = 0
        self.query_times = []

    def embed_text(self, text: str) -> np.ndarray:
        """Generate embedding for a given text."""
        return self.embedding_model.encode([text])[0]

    def add_document(self, document: str):
        """Add a document to the FAISS index."""
        start_time = time.time()
        embedding = self.embed_text(document)
        self.index.add(np.array([embedding], dtype=np.float32))
        self.documents.append(document)
        logger.info(f"Added document. Time: {time.time() - start_time:.4f}s")


    def query(self, question: str, k: int = 1) -> Tuple[str, int]:
        """Query the agent with a question."""
        start_time = time.time()

        # Generate embedding for the question
        question_embedding = self.embed_text(question)

        # Search FAISS index
        distances, indices = self.index.search(np.array([question_embedding], dtype=np.float32), k)

        # Retrieve relevant documents
        context = [self.documents[idx] for idx in indices[0] if idx < len(self.documents)]
        context_text = "\n".join(context)

        #### 1. Prompt Clarity
        #### 4. System Instruction Tuning
        # Prepare prompt
        prompt = f"""
        System: You are a helpful, concise assistant. Given the following context and question, provide specific short answer based on prompt precisely.

        Context:
        {context_text}

        Question:
        {question}

        Please only as much the prompt asked for.
        """


        # Call Ollama Phi-4
        response = ollama.chat(
            model='phi4',
            messages=[{'role': 'user', 'content': prompt}]
        )

        # Track token usage (approximate)
        prompt_tokens = len(prompt.split())
        response_tokens = len(response['message']['content'].split())
        total_tokens = prompt_tokens + response_tokens
        self.token_usage += total_tokens

        # Track query time
        query_time = time.time() - start_time
        self.query_times.append(query_time)

        logger.info(f"Query processed. Time: {query_time:.4f}s, Tokens: {total_tokens}")

        return response['message']['content'], total_tokens

    def get_performance_metrics(self) -> dict:
        """Return performance metrics."""
        return {
            'total_token_usage': self.token_usage,
            'average_query_time': np.mean(self.query_times) if self.query_times else 0,
            'number_of_queries': len(self.query_times)
        }

# Example usage
if __name__ == "__main__":
    agent = SimpleAgent()

    ### 2. Context Window Usage
    question_answer_pair = [
      {
        "question": "What is the capital of France?",
        "answer": "The capital of France is Paris."
      },
      {
        "question": "What is Java?",
        "answer": "Java is a popular programming language."
      },
      {
        "question": "Is the sun a star?",
        "answer": "The sun is a star."
      }
    ]

    # Add sample documents
    documents = [
        "The capital of France is Paris.",
        "Python is a popular programming language.",
        "The sun is a star."
    ]

    for doc in documents:
        agent.add_document(doc)

    # Test queries
    queries = [
        "What is the capital of France?",
        "What is Python?",
        "Is the sun a star?"
    ]

    context = f"Previous Q&A: \n{question_answer_pair}"
    for query in queries:
      #### 2. Context Window Usage
        prompt = f"{context}\nquestion: {query}\nanswer:"
        answer, tokens = agent.query(prompt)

        #### 3. Fallback Strategies
        if not answer:
            prompt2 = f"Retry: {prompt}\nBe concise."
            answer, tokens = agent.query(prompt2)

        print(f"Query: {query}")
        print(f"Answer: {answer}")
        print(f"Tokens used: {tokens}\n")

    # Print performance metrics
    metrics = agent.get_performance_metrics()
    print("Performance Metrics:")
    print(f"Total Token Usage: {metrics['total_token_usage']}")
    print(f"Average Query Time: {metrics['average_query_time']:.4f}s")
    print(f"Number of Queries: {metrics['number_of_queries']}")
# Out:
# Query: What is the capital of France?
# Answer: The capital of France is Paris.
# Tokens used: 89
#
# Query: What is Python?
# Answer: Python is a popular programming language.
#
# (Note: This answer reiterates information already given in the context provided.)
# Tokens used: 98
#
# Query: Is the sun a star?
# Answer: Yes, the sun is a star.
# Tokens used: 88
#
# Performance Metrics:
# Total Token Usage: 275
# Average Query Time: 1.1531s
# Number of Queries: 3

# %% [markdown]
# Performance Improvement: (Comparision)

# %%
# Unoptimised Performance Metrics:
# Token Used for 3 query: 411 + 577 + 517
# Total Token Usage: 1505
# Average Query Time: 56.0968s
# Number of Queries: 3


# Optimised Performance Metrics:
# Token Used for 3 query: 89 + 98 + 88
# Total Token Usage: 275
# Average Query Time: 1.1531s
# Number of Queries: 3
